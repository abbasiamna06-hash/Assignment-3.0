# %% [markdown]
# Question #1

# %%
a = 15
b = 4

print("Sum =", a + b)

print("Difference =", a - b)

print("Product =", a * b)

print("Division =", a / b)

print("Floor Division =", a // b)

print("Modulus =", a % b)
# Out:
# Sum = 19
# Difference = 11
# Product = 60
# Division = 3.75
# Floor Division = 3
# Modulus = 3

# %% [markdown]
# Question #2

# %%
favorite = "Biryani"

print("favorite")
# Out:
# favorite

# %% [markdown]
# Question #3

# %%
apple = 22
mangoes = 33

total_fruits = apple + mangoes

print("Total fruits =", total_fruits)
# Out:
# Total fruits = 55

# %% [markdown]
# Question #4

# %%
num1 = 10
num2 = 5.6
num3 = 4.43
num4 = '23'

print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))

int_to_float = float(num1)
print("Integer to Float:", int_to_float)

float_to_int = int(num2)
print("Float to Integer:", float_to_int)

float_to_string = str(num3)
print("Float to String:", float_to_string)

string_to_int = int(num4)
print("String to Integer:", string_to_int)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# Integer to Float: 10.0
# Float to Integer: 5
# Float to String: 4.43
# String to Integer: 23

# %% [markdown]
# Question #5

# %%
name = "Amna"
age = 19

final_age = age + 1

print("Name:", name)
print("Final Age:", final_age)
# Out:
# Name: Amna
# Final Age: 20

# %% [markdown]
# Question #6

# %%
a = 2
b = 1
c = 6
d = 3


print("Addition:", a + b)

print("Subtraction:", c - a)

print("Multiplication:", d * b)

print("Division:", c / d)

print("Modulus:", c % d)

print("Square of (d + a):", (d + a) ** 2)
# Out:
# Addition: 3
# Subtraction: 4
# Multiplication: 3
# Division: 2.0
# Modulus: 0
# Square of (d + a): 25

# %% [markdown]
# Question #7

# %%
age = 19

age = age + 5

print("Current Age:", age)
# Out:
# Current Age: 24

# %% [markdown]
# Question #8

# %%
a = '2'
b = '11'
c = 6.3

result1 = int(a) + c
print("int(a) + c =", result1)

result2 = float(b) * c
print("float(b) * c =", result2)

result3 = int(c) + c
print("int(c) + c =", result3)
# Out:
# int(a) + c = 8.3
# float(b) * c = 69.3
# int(c) + c = 12.3

# %% [markdown]
# Question #9

# %%
books = 12

books = books - 4

print("Books left:", books)
# Out:
# Books left: 8

# %% [markdown]
# Question #10

# %%
cookies = 5

cookies = cookies * 3

print("Cookies today:", cookies)
# Out:
# Cookies today: 15

# %% [markdown]
# Question #11

# %%
result = 20 - 4 * (3 + 2) + 18 / 3
print(result)
# Out:
# 6.0
